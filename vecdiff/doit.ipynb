# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path

# %%
tcn = ['question', 'answerA', 'answerB', 'answerC', 'answerD']

def read(path):
    td = pd.read_csv(path, '\t')
    
    td['id'] = td['id'].astype(np.uint32)
    td.set_index(['id'], inplace=True)
            
    if 'correctAnswer' in td:
        correctAnswers = td['correctAnswer']
        del td['correctAnswer']
        td.insert(0, 'correctAnswer', correctAnswers.astype('category'))
    
    return td

def clean(td):
    from nltk import word_tokenize as tokenize_words

    from nltk.corpus import stopwords
    stopwords = frozenset(stopwords.words('english'))

    from string import punctuation as punct
    punct = frozenset(punct)

    def tokenize(text):
        words = []
        for token in tokenize_words(text):
            token = token.lower()
            if token in stopwords:
                continue
            if token[-1] in punct:
                continue        
            words.append(token)
        return words
        
    for cn in tcn:
        td[cn] = td[cn].map(tokenize)

    return td

td = read('../data/training_set.tsv')
td = clean(td)

td
# Out:
#        correctAnswer                                           question  \
# id
# 100001             C  [athletes, begin, exercise, heart, rates, resp...
# 100002             C       [example, describes, learned, behavior, dog]
# 100003             D  [two, nuclei, combined, one, nucleus, slight, ...
# 100004             B                  [distinction, epidemic, pandemic]
# 100005             B       [way, orbit, comet, different, orbit, earth]
# 100006             B  [teacher, builds, model, hydrogen, atom, red, ...
# 100007             A  [substance, student, apply, skin, gets, splash...
# 100008             A               [main, source, energy, water, cycle]
# 100009             D  [greatest, effect, aiding, movement, blood, hu...
# 100010             C  [time, non-volcanic, mountains, form, due, int...
# 100011             D  [human, body, average, normal, temperature, 98...
# 100012             D                 [best, explanation, term, ecology]
# 100013             A  [farmer, sprayed, orange, trees, pesticide, el...
# 100014             C  [researchers, work, teams, make, cars, fuel, e...
# 100015             B  [achromatopsia, genetic, disorder, sufferers, ...
# 100016             B       [elements, likely, found, organic, compound]
# 100017             C  [statement, describes, principle, scientists, ...
# 100018             A  [scientist, looks, graph, shows, percentages, ...
# 100019             B  [robots, perform, tasks, dangerous, humans, ma...
# 100020             B  [student, investigated, percentage, energy, ob...
# 100021             C  [voyager, ii, space, probe, launched, 1979, mi...
# 100022             C  [cellular, structure, allows, nutrients, pass,...
# 100023             C    [behavior, help, animals, establish, territory]
# 100024             D  [brain, spinal, cord, nerves, organs, perform,...
# 100025             A       [statement, best, describes, liquid, sample]
# 100026             B  [condition, bees, called, colony, collapse, di...
# 100027             D   [set, contains, kingdoms, contain, heterotrophs]
# 100028             D  [light, passes, lens, eye, produces, image, re...
# 100029             B  [researchers, share, findings, scientists, val...
# 100030             B  [ancient, greeks, tried, discover, laws, unive...
# ...              ...                                                ...
# 102471             B  [large, complex, molecules, found, living, org...
# 102472             B  [interior, earth, made, several, physically, d...
# 102473             B                            [building, dam, likely]
# 102474             B  [periodic, table, elements, group, 18, 8a, hel...
# 102475             B  [following, statements, best, explains, tilt, ...
# 102476             D  [example, organism, selectively, bred, particu...
# 102477             B  [sample, cylindrical, container, cylindrical, ...
# 102478             C  [irregular, intervals, three, seven, years, wa...
# 102479             D  [two, seismographs, placed, 500, km, active, f...
# 102480             D  [sperm, contains, alleles, hqt, fuses, egg, co...
# 102481             C  [fertilization, results, combination, two, cells]
# 102482             C  [invention, would, culture, living, arctic, ci...
# 102483             A  [nuclear, fusion, source, energy, stars, besid...
# 102484             C  [following, statements, best, defines, astrono...
# 102485             D  [south, america, africa, two, continents, sepa...
# 102486             B  [lighting, match, baking, cake, two, actions, ...
# 102487             C  [common, way, humans, contribute, extinction, ...
# 102488             A  [taxonomic, group, organisms, found, share, ch...
# 102489             B  [females, begin, producing, sex, cells, called...
# 102490             C  [following, substances, pass, across, placenta...
# 102491             C                       [surface, currents, develop]
# 102492             B  [baby, kit, fox, grows, become, adult, mass, 3...
# 102493             A  [following, believed, one, cause, global, warm...
# 102494             B  [abundance, mineral, surface, earth, likely, d...
# 102495             A  [many, environmental, changes, earth, 's, hist...
# 102496             B  [element, property, would, best, use, electric...
# 102497             B  [pollen, grains, cells, specialized, sexual, r...
# 102498             D                            [biodiversity, altered]
# 102499             B  [cellular, respiration, process, organisms, fo...
# 102500             D  [scientist, working, pharmaceutical, company, ...
#
#                                                   answerA  \
# id
# 100001                                    [tissue, level]
# 100002                             [smelling, air, odors]
# 100003                                       [conversion]
# 100004                                [symptoms, disease]
# 100005       [orbit, earth, less, circular, orbit, comet]
# 100006                                [number, particles]
# 100007                                            [water]
# 100008                                              [sun]
# 100009                                          [tension]
# 100010      [oceanic, plates, colliding, oceanic, plates]
# 100011                   [decrease, sugar, levels, blood]
# 100012             [study, nonliving, parts, environment]
# 100013                               [natural, selection]
# 100014                      [research, likely, published]
# 100015                                       [rod, cells]
# 100016                                           [helium]
# 100017         [solid, materials, absorb, seismic, waves]
# 100018                                       [bar, graph]
# 100019                    [assembly, pieces, must, small]
# 100020                                            [table]
# 100021                                           [meters]
# 100022                                    [mitochondrion]
# 100023              [caribou, herd, migrates, seasonally]
# 100024                 [supporting, body, enabling, move]
# 100025   [retain, volume, transferred, larger, container]
# 100026                 [would, decrease, soil, thickness]
# 100027                                  [protists, fungi]
# 100028                                          [smaller]
# 100029     [e-mail, research, results, local, newspapers]
# 100030                                         [analysis]
# ...                                                   ...
# 102471                   [water, carbon, dioxide, oxygen]
# 102472                                             [core]
# 102473                        [prevent, water, pollution]
# 102474                                     [lighter, air]
# 102475  [warm, ocean, currents, flow, tropics, norther...
# 102476                                  [cats, eat, mice]
# 102477                                      [must, solid]
# 102478                                        [hurricane]
# 102479                             [pull, gravity, waves]
# 102480                                           [hhqqtt]
# 102481                                  [two, egg, cells]
# 102482                                  [ice, production]
# 102483                                           [helium]
# 102484  [amount, time, takes, light, travel, space, on...
# 102485          [continents, created, volcanic, activity]
# 102486                            [change, state, matter]
# 102487                                  [rotation, crops]
# 102488                                         [bacteria]
# 102489                          [reach, sexual, maturity]
# 102490                                           [oxygen]
# 102491                           [friction, ocean, rocks]
# 102492                              [size, fox, 's, ears]
# 102493               [atmospheric, rise, carbon, dioxide]
# 102494                      [climate, particular, region]
# 102495                                          [extinct]
# 102496                                        [insulator]
# 102497                                            [genes]
# 102498          [unexpected, changes, climate, ecosystem]
# 102499                                         [products]
# 102500                          [cold, medicines, tested]
#
#                                                   answerB  \
# id
# 100001                                     [organ, level]
# 100002                               [barking, disturbed]
# 100003                                         [reaction]
# 100004                     [geographical, area, affected]
# 100005           [orbit, comet, elliptical, orbit, earth]
# 100006                        [relative, mass, particles]
# 100007                                          [vinegar]
# 100008                                    [fossil, fuels]
# 100009                                         [friction]
# 100010     [oceanic, plates, separating, oceanic, plates]
# 100011                   [increase, sugar, levels, blood]
# 100012                [study, living, parts, environment]
# 100013                              [selective, breeding]
# 100014                   [research, costs, less, perform]
# 100015                                      [cone, cells]
# 100016                                         [hydrogen]
# 100017        [magnetic, fields, deflect, seismic, waves]
# 100018                                      [scatterplot]
# 100019         [assembly, process, must, remain, exactly]
# 100020                                       [pie, chart]
# 100021                                       [kilometers]
# 100022                                          [nucleus]
# 100023          [scent, trail, leads, ants, food, source]
# 100024  [transporting, oxygen, wastes, nutrients, thro...
# 100025     [keeps, shape, transferred, larger, container]
# 100026                [would, decline, fruit, production]
# 100027                                [bacteria, animals]
# 100028                                           [larger]
# 100029  [publish, research, results, scientific, journal]
# 100030                                       [experiment]
# ...                                                   ...
# 102471               [carbohydrates, fats, proteins, dna]
# 102472                                            [crust]
# 102473          [destroy, habitat, many, animal, species]
# 102474                    [full, outer, electron, shells]
# 102475  [rays, sun, strike, northern, hemisphere, dire...
# 102476                               [cows, graze, grass]
# 102477                     [could, either, solid, liquid]
# 102478                                          [tornado]
# 102479                        [interaction, light, waves]
# 102480                                           [hhqqtt]
# 102481                                [two, sperm, cells]
# 102482                                [air, conditioning]
# 102483                                         [nitrogen]
# 102484          [measure, bright, object, appears, space]
# 102485      [fossils, brought, south, america, explorers]
# 102486                          [create, new, substances]
# 102487                                 [use, fertilizers]
# 102488                                            [fungi]
# 102489                                             [born]
# 102490                                           [wastes]
# 102491                     [mixture, minerals, saltwater]
# 102492                     [conditions, fox, 's, habitat]
# 102493              [hot, air, air, conditioner, exhaust]
# 102494                [types, elements, available, crust]
# 102495                                 [evolved, animals]
# 102496                                        [conductor]
# 102497                                            [sperm]
# 102498                                  [fire, ecosystem]
# 102499                                        [reactants]
# 102500                  [medicine, used, treat, ailments]
#
#                                                   answerC  \
# id
# 100001                                    [system, level]
# 100002                                 [sitting, command]
# 100003                                          [fission]
# 100004                     [species, organisms, infected]
# 100005  [orbital, period, earth, much, longer, orbital...
# 100006                        [types, particles, present]
# 100007                                             [salt]
# 100008                                           [clouds]
# 100009                                          [density]
# 100010  [continental, plates, colliding, continental, ...
# 100011                      [decrease, blood, flow, skin]
# 100012   [study, protection, renewal, natural, resources]
# 100013                             [aerobic, respiration]
# 100014                        [researchers, share, ideas]
# 100015                                             [lens]
# 100016                                          [mercury]
# 100017  [density, material, affects, speed, seismic, w...
# 100018                                    [circle, graph]
# 100019            [robots, require, regular, maintenance]
# 100020                                       [bar, graph]
# 100021                              [astronomical, units]
# 100022                                         [membrane]
# 100023      [wolf, pack, howls, warn, wolves, stay, away]
# 100024                 [producing, male, female, gametes]
# 100025       [volume, greatly, reduced, adding, pressure]
# 100026                 [would, increase, plant, diseases]
# 100027                                    [plants, fungi]
# 100028                                          [upright]
# 100029             [publish, results, brochures, doctors]
# 100030                                       [conclusion]
# ...                                                   ...
# 102471             [carbohydrates, proteins, water, salt]
# 102472                                    [asthenosphere]
# 102473                 [allow, fish, easily, swim, river]
# 102474                         [excess, electrons, share]
# 102475  [greenhouse, effect, increases, northern, hemi...
# 102476                         [pigs, form, large, herds]
# 102477                                     [must, liquid]
# 102478                                         [el, niño]
# 102479            [differences, strength, waves, origins]
# 102480                                           [hhqqtt]
# 102481                           [egg, cell, sperm, cell]
# 102482                              [insulated, clothing]
# 102483                                           [oxygen]
# 102484                    [average, distance, sun, earth]
# 102485  [animals, crossed, land, bridge, connected, co...
# 102486                                   [change, volume]
# 102487                             [destruction, habitat]
# 102488                                           [plants]
# 102489                       [engaging, sexual, activity]
# 102490                                            [blood]
# 102491                            [friction, ocean, wind]
# 102492                  [average, number, fox, offspring]
# 102493                [methane, gas, escaping, landfills]
# 102494                [thicknesses, nearby, rock, layers]
# 102495                            [plant-like, organisms]
# 102496                                        [malleable]
# 102497                                           [testes]
# 102498                                 [flood, ecosystem]
# 102499                                  [waste, products]
# 102500                 [scientists, make, cold, medicine]
#
#                                                   answerD
# id
# 100001                                  [cellular, level]
# 100002                                    [digging, soil]
# 100003                                           [fusion]
# 100004                         [season, disease, spreads]
# 100005  [orbital, period, comet, predictable, orbital,...
# 100006                      [charges, particles, present]
# 100007                                     [formaldehyde]
# 100008                                            [ocean]
# 100009                                          [gravity]
# 100010  [continental, plates, separating, continental,...
# 100011                      [increase, blood, flow, skin]
# 100012      [study, organisms, interactions, environment]
# 100013                             [sexual, reproduction]
# 100014                [researchers, time, complete, work]
# 100015                                             [iris]
# 100016                                              [tin]
# 100017  [physical, state, material, determines, amplit...
# 100018                                       [pictograph]
# 100019              [robots, must, provided, electricity]
# 100020                                      [line, graph]
# 100021                                     [light, years]
# 100022                                      [chloroplast]
# 100023        [honeybee, society, divides, work, members]
# 100024  [conducting, messages, coordinate, body, funct...
# 100025          [shape, changed, increasing, temperature]
# 100026       [would, increase, insect, pest, populations]
# 100027                                   [animals, fungi]
# 100028                                          [inverse]
# 100029             [discuss, research, results, internet]
# 100030                                      [observation]
# ...                                                   ...
# 102471               [hydrogen, carbon, oxygen, nitrogen]
# 102472                                       [atmosphere]
# 102473                    [cause, people, consume, water]
# 102474                          [easily, react, elements]
# 102475        [northern, hemisphere, closer, sun, summer]
# 102476                       [chickens, lay, large, eggs]
# 102477                       [could, either, liquid, gas]
# 102478                                       [santa, ana]
# 102479                  [different, media, waves, travel]
# 102480                                           [hhqqtt]
# 102481                              [two, somatic, cells]
# 102482                               [irrigation, canals]
# 102483                                          [uranium]
# 102484     [distance, earth, 's, revolution, around, sun]
# 102485             [continents, attached, drifted, apart]
# 102486                                   [create, energy]
# 102487                 [introduction, competing, species]
# 102488                                          [animals]
# 102489                        [beginning, monthly, cycle]
# 102490                                        [nutrients]
# 102491               [mixture, freshwater, deltas, rocks]
# 102492       [social, behaviors, within, fox, population]
# 102493            [body, heat, generated, overpopulation]
# 102494                  [exposure, elements, environment]
# 102495                                 [affected, humans]
# 102496                                           [porous]
# 102497                                             [eggs]
# 102498                                                 []
# 102499                                            [gases]
# 102500            [results, accurately, reported, public]
#
# [2500 rows x 6 columns]

# %%
vs = 300

def build_feature_extractor(texts):
    from gensim.models.doc2vec import Doc2Vec, TaggedDocument
    from multiprocessing import cpu_count
    
    model = Doc2Vec(
        [TaggedDocument(t, [i]) for i, t in enumerate(texts)],
        workers=cpu_count(),

        size=vs,
    )
    
    def extract_features(text):
        return model.infer_vector(text).astype(np.float32)
    
    return extract_features


extract_features = build_feature_extractor(t for cn in tcn for t in td[cn].values)

if Path('features.pkl').exists():
    vd = pd.read_pickle('features.pkl')
else:
    tfcn_for = {cn: ['%s_feature_%d' % (cn, i) for i in range(vs)] for cn in tcn}
    tfcn = [fcn for cn in tcn for fcn in tfcn_for[cn]]
    vd = pd.DataFrame(index=td.index, columns=['correctAnswer'] + tfcn)
    vd['correctAnswer'] = td['correctAnswer']
    vd[tfcn] = vd[tfcn].astype(np.float32)
    vd = vd.to_dense()

    for i in tqdm(td.index):
        for cn in tcn:
            vd.loc[i, tfcn_for[cn]] = extract_features(td[cn][i])
    
    vd.to_pickle('features.pkl')
    
vd
# Out:
#        correctAnswer  question_feature_0  question_feature_1  \
# id
# 100001             C            0.000855            0.000188
# 100002             C           -0.000790            0.005058
# 100003             D           -0.001595            0.007671
# 100004             B            0.006605           -0.013449
# 100005             B            0.002086           -0.006844
# 100006             B            0.002376           -0.004986
# 100007             A           -0.004044            0.006757
# 100008             A           -0.003005            0.001872
# 100009             D            0.000818           -0.000452
# 100010             C           -0.000049           -0.005234
# 100011             D            0.007548           -0.013927
# 100012             D           -0.000054           -0.000888
# 100013             A           -0.000244            0.002023
# 100014             C            0.000224            0.000459
# 100015             B            0.003429           -0.004253
# 100016             B            0.001903           -0.008390
# 100017             C           -0.001372            0.001853
# 100018             A            0.005378           -0.007684
# 100019             B           -0.006865            0.011316
# 100020             B            0.006272           -0.011226
# 100021             C            0.004737           -0.006611
# 100022             C            0.002724           -0.008817
# 100023             C            0.003418           -0.003998
# 100024             D           -0.001058            0.005437
# 100025             A           -0.000617            0.006219
# 100026             B            0.005333           -0.009542
# 100027             D            0.004119           -0.003911
# 100028             D           -0.000772            0.002845
# 100029             B           -0.004025            0.002637
# 100030             B            0.002989           -0.003566
# ...              ...                 ...                 ...
# 102471             B           -0.002473            0.002759
# 102472             B           -0.006706            0.004934
# 102473             B            0.001517            0.003308
# 102474             B           -0.002134            0.003953
# 102475             B            0.000155            0.005011
# 102476             D           -0.000804           -0.000308
# 102477             B           -0.003459            0.005018
# 102478             C           -0.001484            0.008405
# 102479             D           -0.002374            0.005529
# 100024             0.001795        -2.330333e-03            -0.000253
# 100025             0.000151        -3.095740e-04             0.005289
# 100026            -0.000037         1.005611e-03             0.003094
# 100027            -0.001015         5.692274e-03             0.019130
# 100028             0.001416         1.359066e-03            -0.000257
# 100029             0.000374         9.750669e-04             0.001123
# 100030            -0.002096         2.641975e-03             0.012468
# ...                     ...                  ...                  ...
# 102471            -0.000529        -8.113938e-04            -0.012461
# 102472             0.002335        -5.044348e-03            -0.022649
# 102473            -0.002145         1.840335e-04             0.001574
# 102474            -0.000045        -2.382354e-04             0.001905
# 102475            -0.000734         1.808356e-03             0.000945
# 102476             0.002816        -5.664782e-03            -0.020955
# 102477             0.001073        -3.497737e-03            -0.014145
# 102478            -0.001510         8.472420e-04            -0.000893
# 102479             0.000861        -1.624507e-03             0.002677
# 102480            -0.000946        -8.154755e-04             0.000513
# 102481            -0.002111         2.415625e-03             0.011810
# 102482             0.001322        -1.321390e-03            -0.000021
# 102483             0.001146        -4.233386e-03            -0.023493
# 102484             0.000431         1.899115e-03             0.007519
# 102485             0.000048        -6.129363e-03            -0.021308
# 102486             0.000668         3.156036e-04            -0.000474
# 102487            -0.000265         1.476299e-03             0.008984
# 102488            -0.000860         4.437495e-03             0.017987
# 102489            -0.002157         2.424425e-03             0.008890
# 102490            -0.001806         2.743947e-03             0.018908
# 102491             0.002168        -2.919648e-03            -0.011675
# 102492            -0.000025        -2.337657e-03            -0.013006
# 102493             0.000306        -2.011530e-04             0.000103
# 102494            -0.000734         4.544362e-05            -0.004452
# 102495            -0.000901        -7.959360e-04             0.001446
# 102496            -0.001466        -1.090715e-04             0.000500
# 102497            -0.000513        -4.310781e-03            -0.022795
# 102498             0.001207         1.576398e-03             0.001536
# 102499             0.002905        -5.620723e-03            -0.019419
# 102500             0.001194         5.488553e-04            -0.008814
#
# [2500 rows x 1501 columns]

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from scipy.spatial import distance

class MyClassifier(BaseEstimator, ClassifierMixin):
    def fit(self, X, y):
        if X.shape[0] != y.shape[0]:
            raise ValueError('X.rows != y.rows')

        self.question_essence = X[:, :vs].mean(axis=0)
        
        correct_answers = np.zeros((X.shape[0], vs))
        for i in range(X.shape[0]):
            j = ord(y[i]) - ord('A')
            o = (1 + j) * vs
            correct_answers[i, :] = X[i, o:o + vs]
        self.correct_answer_essence = correct_answers.mean(axis=0)
        
        return self

    def predict(self, X):
        y = np.empty(X.shape[0], dtype=object)
        
        for i in range(X.shape[0]):
            question = X[i, :vs]
            quasi_correct_answer = question - self.question_essence + self.correct_answer_essence
            
            answers = np.zeros((4, vs))
            for j in range(4):
                o = (1 + j) * vs
                answers[j] = X[i, o:o + vs]
            
            j = np.argmin([distance.cosine(a, quasi_correct_answer) for a in answers])
            y[i] = chr(ord('A') + j)

        return y

# %%
from sklearn.cross_validation import cross_val_score

v = vd.as_matrix()

mc = MyClassifier()

cross_val_score(mc, v[:, 1:], v[:, 0], cv=10, scoring='accuracy').mean()
# Out:
# 0.24840307921117213
